# %%
import os
import glob
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import platform

# %%
## Paths Input Here
analysis = 'cleaned_data'
if platform.uname().system == 'Darwin': #------------------------------Mac OS X---------------------------------------------------------------
    conn_path = r'/Users/cu135/Dropbox (Partners HealthCare)/resources/datasets/BIDS_PD_DBS_STN_WURZBURG/metadata/subiculum_roi_connectivity/matrix_corrMx_T (5).csv'
    clin_path = r'/Users/cu135/Dropbox (Partners HealthCare)/resources/datasets/BIDS_PD_DBS_STN_WURZBURG/metadata/cog_decline_scores.csv'
    # clin_path = 'path to clinical values'
    out_name = os.path.basename(conn_path).split('.csv')[0]
    out_dir = os.path.join(os.path.dirname(conn_path), out_name)
    #out_dir = r'path to out dir here'
    x_roi_names = r'/Users/cu135/Dropbox (Partners HealthCare)/resources/datasets/BIDS_PD_DBS_STN_WURZBURG/metadata/subiculum_roi_connectivity/matrix_corrMx_names (5).csv'
    #roi_names = '<path to roi name location>'
    print('I have set pathnames in the Mac style')
else: #----------------------------------------------------------------Windows----------------------------------------------------------------
    conn_path = r'C:\Users\calvin.howard\Dropbox (Partners HealthCare)\memory\analyses\roi-roi_correl\matrix_corrMx_AvgR.csv'
    clin_path = r'C:\Users\calvin.howard\Dropbox (Partners HealthCare)\memory\patient_data\AD_Clinical_Data_CDR_ADAS_COG_13.xlsx'
    # clin_path = 'path to clinical values'
    out_dir = r'C:\Users\calvin.howard\Dropbox (Partners HealthCare)\memory\analyses\AD_to_memory_net'
    #out_dir = r'path to out dir here'
    x_roi_names = r'C:\Users\calvin.howard\Dropbox (Partners HealthCare)\memory\analyses\roi-roi_correl\matrix_corrMx_names.csv'
    #roi_names = '<path to roi name location>'
    print('I have set pathnames in the Windows style')

##User Input Goes Here
x_cols = [1] #enter target data columns (indexed from 0)
#x_roi_names = r'C:\Users\calvin.howard\Dropbox (Partners HealthCare)\memory\analyses\spcorrel\vtafxconn-yeoseed\cta_conn_names.csv'
#roi_names = '<path to roi name location>'
# Out:
# I have set pathnames in the Mac style

# %% [markdown]
# ## Importing Dataframe
# The critical step is to develop an indication of patient ID.
# The patient ID is used ot conjoin to clinical responses.

# %%
sort = False


#----------------------------------------------------------------Do not change below----------------------------------------------------------------
from calvin_utils.regex_functions import extract_digits

#Step 1) Import the data
try:
    name_df = pd.read_csv(x_roi_names, names=['arb'], header=None)
    name_df.tail(5)
    colnames = name_df.arb.values.tolist()
    newname = []
    for name in colnames:
        arb = os.path.basename(name).split('.nii')[0]
        arb = arb[0::]
        newname.append(arb)

    x_df = pd.read_csv(conn_path, names=newname, header=None)#, ignore_index=True)
    x_df.index = newname
    x_df = x_df.iloc[:,:]
    x_df = x_df.reset_index(drop=True)
    names=[]
    for name in x_df.columns.values.tolist():
        try:
            names.append(extract_digits(name)[0])
        except:
            names.append(name)
    print(names)
    x_df['Patient # CDR, ADAS'] = names
    x_df = x_df.set_index('Patient # CDR, ADAS')
except:
    print('excepted')
    x_df = pd.read_csv(conn_path)
    
display(x_df)
# Out:
# ['01', '02', '04', '03', '06', '07', '09', '11', '12', '14', '15', '17', '19', '18', '21', '22', '23', '24', '26', '27', '28', '29', '30', '31', '33', '34', '36', '37', '38', '39', '43', '44', 'memory_roi']
#                      MDST01_seed_compound_fMRI  MDST02_seed_compound_fMRI  \
# Patient # CDR, ADAS
# 01                                         NaN                 109.571458
# 02                                  109.571458                        NaN
# 04                                  103.404972                  93.284773
# 03                                  104.310198                 141.402385
# 06                                   85.688171                 131.229409
# 07                                   74.779218                  66.815075
# 09                                   84.928811                  92.861765
# 11                                   83.792620                 133.197514
# 12                                  108.589073                 138.898718
# 14                                  111.831722                 102.025537
# 15                                   58.725466                  48.290666
# 17                                   84.558161                 107.713587
# 19                                  102.727280                 136.369242
# 18                                  118.813043                 158.459632
# 21                                  177.816822                  82.852147
# 22                                   77.212454                 102.985364
# 23                                   99.698816                 197.832428
# 24                                   88.544440                 164.889888
# 26                                   84.272737                  80.981231
# 27                                   85.946957                 167.306872
# 28                                  102.677733                 112.985185
# 29                                   92.693363                  99.111610
# 30                                   80.954753                 136.222893
# 31                                  113.929750                 162.916648
# 33                                   65.705712                 150.702342
# 34                                   94.798299                  73.699656
# 36                                   64.117937                  79.458982
# 37                                  196.438785                 113.722834
# 38                                   66.202761                 137.784793
# 39                                  108.323090                 135.022364
# 43                                   91.028559                 264.738053
# 44                                  102.874886                 167.490427
# memory_roi                           30.376565                  16.295870
#
#                      MDST04_seed_compound_fMRI  MDST03_seed_compound_fMRI  \
# Patient # CDR, ADAS
# 01                                  103.404972                 104.310198
# 02                                   93.284773                 141.402385
# 04                                         NaN                  74.107998
# 03                                   74.107998                        NaN
# 06                                  106.988286                 183.418386
# 07                                   55.421347                 149.123859
# 09                                  236.344621                  67.680136
# 11                                  182.774445                 101.502387
# 12                                   84.278895                 201.095657
# 14                                  331.526852                  71.520772
# 15                                   67.578929                  75.716970
# 17                                   66.085468                 221.494206
# 19                                  111.917664                 188.151994
# 18                                  159.375745                  85.836446
# 21                                  151.069145                  77.830900
# 22                                  107.288018                 133.314876
# 23                                   94.359754                 119.342404
# 24                                   85.487932                 234.352145
# 26                                  119.567602                 123.021134
# 27                                  115.668941                 157.661906
# 28                                   68.206845                 282.495567
# 29                                   81.914573                 199.778352
# 30                                  120.571271                 149.600676
# 31                                  153.242056                 109.287179
# 33                                   82.206837                  87.728883
# 34                                   55.131205                 189.457848
# 36                                  200.795387                  59.966315
# 37                                  174.933814                  65.715802
# 38                                  126.215813                  83.173913
# 39                                  158.980499                 125.682186
# 43                                   83.084265                 154.050788
# 44                                   98.697114                 110.556482
# memory_roi                           21.207602                  30.900051
#
#                      MDST06_seed_compound_fMRI  MDST07_seed_compound_fMRI  \
# Patient # CDR, ADAS
# 01                                   85.688171                  74.779218
# 02                                  131.229409                  66.815075
# 04                                  106.988286                  55.421347
# 03                                  183.418386                 149.123859
# 06                                         NaN                 129.345440
# 07                                  129.345440                        NaN
# 09                                   87.382192                  46.152289
# 11                                  168.076895                  63.226682
# 12                                  156.947427                 168.869863
# 14                                  102.188115                  49.106795
# 15                                   75.818872                  98.696423
# 17                                  181.835309                 180.402254
# 19                                  200.714184                 122.072803
# 18                                  116.352252                  57.392064
# 21                                   93.290731                  73.118425
# 22                                  234.134156                  90.909846
# 23                                  117.861476                  60.073430
# 24                                  209.089132                 143.344458
# 26                                  181.938427                 115.210259
# 27                                  233.319574                  94.439573
# 28                                  172.545456                 133.017282
# 29                                  189.100216                 146.246123
# 30                                  236.152828                  86.467282
# 31                                  141.762826                  61.488303
# 33                                  109.651244                  42.471611
# 34                                  134.140080                 140.803184
# 36                                   96.181753                  44.839366
# 37                                   83.993924                  44.482297
# 38                                  114.140448                  44.966310
# 39                                  180.171066                 102.877347
# 43                                  147.395512                  93.435590
# 44                                   97.706138                  57.634938
# memory_roi                           23.577739                  36.657479
#
#                      MDST09_seed_compound_fMRI  MDST11_seed_compound_fMRI  \
# Patient # CDR, ADAS
# 01                                   84.928811                  83.792620
# 02                                   92.861765                 133.197514
# 04                                  236.344621                 182.774445
# 03                                   67.680136                 101.502387
# 06                                   87.382192                 168.076895
# 07                                   46.152289                  63.226682
# 09                                         NaN                 143.120197
# 11                                  143.120197                        NaN
# 12                                   71.093741                 101.720565
# 14                                  273.596130                 185.672174
# 15                                   53.451351                  58.118861
# 17                                   55.290178                  86.347574
# 19                                   84.562305                 136.713160
# 18                                  136.546864                 173.810556
# 21                                   99.479323                 102.860478
# 22                                   78.197276                 170.232781
# 23                                   91.709288                 129.926656
# 24                                   75.450576                 126.505869
# 26                                   78.751554                 146.572443
# 27                                   91.106163                 179.924366
# 28                                   59.237130                  94.133342
# 29                                   63.031987                 108.496530
# 30                                   92.728378                 191.536432
# 31                                  121.559864                 192.735132
# 33                                   77.082468                 125.176990
# 34                                   41.582637                  65.616853
# 36                                  158.791726                 183.581618
# 37                                  144.629757                 131.582614
# 38                                  113.223933                 184.719664
# 39                                  119.126932                 201.002403
# 43                                   77.136465                 124.750969
# 44                                  114.534658                 114.905859
# memory_roi                           19.955774                  15.156220
#
#                      MDST12_seed_compound_fMRI  MDST14_seed_compound_fMRI  \
# Patient # CDR, ADAS
# 01                                  108.589073                 111.831722
# 02                                  138.898718                 102.025537
# 04                                   84.278895                 331.526852
# 03                                  201.095657                  71.520772
# 06                                  156.947427                 102.188115
# 07                                  168.869863                  49.106795
# 09                                   71.093741                 273.596130
# 11                                  101.720565                 185.672174
# 12                                         NaN                  80.485592
# 14                                   80.485592                        NaN
# 15                                   85.981917                  56.569447
# 17                                  187.118952                  60.121348
# 19                                  193.483670                  99.314964
# 18                                  108.338548                 178.470437
# 21                                  110.120522                 142.277911
# 22                                  110.566493                  97.026855
# 23                                  134.352788                 104.348916
# 24                                  211.504994                  82.426387
# 26                                  124.082902                 101.164345
# 27                                  141.468866                 106.598302
# 28                                  146.000951                  63.595276
# 29                                  159.450691                  71.247939
# 30                                  123.906017                 110.725493
# 31                                  108.511868                 148.475493
# 33                                   70.369501                  86.327345
# 34                                  133.298653                  46.996398
# 36                                   62.371089                 199.271917
# 37                                   85.174051                 203.991649
# 38                                   75.351770                 125.959530
# 39                                  159.750798                 166.044216
# 43                                  158.227758                  86.039666
# 44                                  132.589496                 114.925087
# memory_roi                           28.328345                  19.619016
#
#                      ...  MDST31_seed_compound_fMRI  \
# Patient # CDR, ADAS  ...
# 01                   ...                 113.929750
# 02                   ...                 162.916648
# 04                   ...                 153.242056
# 03                   ...                 109.287179
# 06                   ...                 141.762826
# 07                   ...                  61.488303
# 09                   ...                 121.559864
# 11                   ...                 192.735132
# 12                   ...                 108.511868
# 14                   ...                 148.475493
# 15                   ...                  58.003509
# 17                   ...                  91.678874
# 19                   ...                 171.150031
# 18                   ...                 150.017806
# 21                   ...                 112.405399
# 22                   ...                 156.639293
# 23                   ...                 148.521252
# 24                   ...                 124.249577
# 26                   ...                 141.578741
# 27                   ...                 175.650274
# 28                   ...                 102.829171
# 29                   ...                 122.911084
# 30                   ...                 193.876827
# 31                   ...                        NaN
# 33                   ...                 142.725369
# 34                   ...                  82.578755
# 36                   ...                 129.890944
# 37                   ...                 140.906109
# 38                   ...                 195.877141
# 39                   ...                 138.818591
# 43                   ...                 130.861096
# 44                   ...                 132.255439
# memory_roi           ...                  15.353030
#
#                      MDST33_seed_compound_fMRI  MDST34_seed_compound_fMRI  \
# Patient # CDR, ADAS
# 01                                   65.705712                  94.798299
# 02                                  150.702342                  73.699656
# 04                                   82.206837                  55.131205
# 03                                   87.728883                 189.457848
# 06                                  109.651244                 134.140080
# 07                                   42.471611                 140.803184
# 09                                   77.082468                  41.582637
# 11                                  125.176990                  65.616853
# 12                                   70.369501                 133.298653
# 14                                   86.327345                  46.996398
# 15                                   37.467211                  81.297149
# 17                                   70.086562                 177.285267
# 19                                   89.448426                 153.406033
# 18                                   85.926841                  54.779576
# 21                                   56.216479                  75.872126
# 22                                  116.529233                 131.607664
# 23                                  183.839440                  55.621238
# 24                                   94.174511                 128.983504
# 26                                   68.157129                 145.188613
# 27                                  122.937583                 118.327035
# 28                                   84.592518                 259.475619
# 29                                   76.157244                 225.944222
# 30                                  145.974824                 119.499560
# 31                                  142.725369                  82.578755
# 33                                         NaN                  57.643753
# 34                                   57.643753                        NaN
# 36                                  106.536792                  51.804942
# 37                                   74.542711                  42.603116
# 38                                  185.906880                  54.379488
# 39                                   80.176279                  80.200568
# 43                                  157.191037                  90.340285
# 44                                  105.229963                  42.747091
# memory_roi                           15.050219                  34.047011
#
#                      MDST36_seed_compound_fMRI  MDST37_seed_compound_fMRI  \
# Patient # CDR, ADAS
# 01                                   64.117937                 196.438785
# 02                                   79.458982                 113.722834
# 04                                  200.795387                 174.933814
# 03                                   59.966315                  65.715802
# 06                                   96.181753                  83.993924
# 07                                   44.839366                  44.482297
# 09                                  158.791726                 144.629757
# 11                                  183.581618                 131.582614
# 12                                   62.371089                  85.174051
# 14                                  199.271917                 203.991649
# 15                                   50.486077                  49.027660
# 17                                   57.812138                  56.145473
# 19                                   87.914365                  95.495236
# 18                                  113.217550                 195.995707
# 21                                   90.502170                 190.990553
# 22                                  119.742152                  77.913394
# 23                                   92.368027                 113.584119
# 24                                   71.227987                  76.448013
# 26                                  101.116170                  83.619157
# 27                                  110.028955                  94.844263
# 28                                   60.812692                  55.423809
# 29                                   70.681675                  62.514354
# 30                                  125.105226                  87.874506
# 31                                  129.890944                 140.906109
# 33                                  106.536792                  74.542711
# 34                                   51.804942                  42.603116
# 36                                         NaN                 114.528736
# 37                                  114.528736                        NaN
# 38                                  154.060848                  97.108643
# 39                                  109.703862                 143.319189
# 43                                   83.233075                  87.604394
# 44                                   85.055676                 125.912765
# memory_roi                           17.382020                  17.978233
#
#                      MDST38_seed_compound_fMRI  MDST39_seed_compound_fMRI  \
# Patient # CDR, ADAS
# 01                                   66.202761                 108.323090
# 02                                  137.784793                 135.022364
# 04                                  126.215813                 158.980499
# 03                                   83.173913                 125.682186
# 06                                  114.140448                 180.171066
# 07                                   44.966310                 102.877347
# 09                                  113.223933                 119.126932
# 11                                  184.719664                 201.002403
# 12                                   75.351770                 159.750798
# 14                                  125.959530                 166.044216
# 15                                   48.002387                  73.468415
# 17                                   68.196696                 110.751942
# 19                                  105.965676                 159.423849
# 18                                  117.440982                 203.367166
# 21                                   72.181726                 137.845083
# 22                                  124.830667                 128.427412
# 23                                  137.310706                 123.882985
# 24                                   99.030483                 151.530505
# 26                                   90.995619                 155.849049
# 27                                  147.499474                 151.546894
# 28                                   80.938307                 101.861595
# 29                                   87.991085                 117.314111
# 30                                  169.883661                 136.357993
# 31                                  195.877141                 138.818591
# 33                                  185.906880                  80.176279
# 34                                   54.379488                  80.200568
# 36                                  154.060848                 109.703862
# 37                                   97.108643                 143.319189
# 38                                         NaN                 102.751061
# 39                                  102.751061                        NaN
# 43                                  127.277955                 130.893306
# 44                                  112.063081                 119.195477
# memory_roi                           14.611144                  21.551613
#
#                      MDST43_seed_compound_fMRI  MDST44_seed_compound_fMRI  \
# Patient # CDR, ADAS
# 01                                   91.028559                 102.874886
# 02                                  264.738053                 167.490427
# 04                                   83.084265                  98.697114
# 03                                  154.050788                 110.556482
# 06                                  147.395512                  97.706138
# 07                                   93.435590                  57.634938
# 09                                   77.136465                 114.534658
# 11                                  124.750969                 114.905859
# 12                                  158.227758                 132.589496
# 14                                   86.039666                 114.925087
# 15                                   58.592295                  37.809573
# 17                                  139.313582                  86.986090
# 19                                  141.601583                 109.777789
# 18                                  132.292015                 126.531154
# 21                                   75.113879                  84.385279
# 22                                  115.015353                  70.835819
# 23                                  165.460411                 244.702118
# 24                                  187.409325                 132.173668
# 26                                   89.603428                  59.130700
# 27                                  187.029215                 101.139289
# 28                                  125.238847                  74.077189
# 29                                  110.772315                  68.859780
# 30                                  146.497648                  97.450064
# 31                                  130.861096                 132.255439
# 33                                  157.191037                 105.229963
# 34                                   90.340285                  42.747091
# 36                                   83.233075                  85.055676
# 37                                   87.604394                 125.912765
# 38                                  127.277955                 112.063081
# 39                                  130.893306                 119.195477
# 43                                         NaN                 120.868303
# 44                                  120.868303                        NaN
# memory_roi                           20.200341                  14.468351
#
#                      memory_roi
# Patient # CDR, ADAS
# 01                    30.376565
# 02                    16.295870
# 04                    21.207602
# 03                    30.900051
# 06                    23.577739
# 07                    36.657479
# 09                    19.955774
# 11                    15.156220
# 12                    28.328345
# 14                    19.619016
# 15                    39.316089
# 17                    30.014730
# 19                    23.128431
# 18                    15.781874
# 21                    26.016428
# 22                    19.953155
# 23                    15.519790
# 24                    24.237392
# 26                    24.468157
# 27                    18.800226
# 28                    32.297293
# 29                    29.015201
# 30                    18.674670
# 31                    15.353030
# 33                    15.050219
# 34                    34.047011
# 36                    17.382020
# 37                    17.978233
# 38                    14.611144
# 39                    21.551613
# 43                    20.200341
# 44                    14.468351
# memory_roi                  NaN
#
# [33 rows x 33 columns]

# %%
# Step 2) Identify the column with Patient ID in it
# Gather patient IDs from data
if 'roi' in x_df.columns:
    print('roi detected')
    #Clean ROI Names
    patient_id = []
    for i in range(0, len(x_df['roi'].values.tolist())):
        roi = x_df['roi'].values.tolist()[i]
        basename = os.path.splitext(roi)[0]
        first_half = basename.split('sub-')[1]
        complete_name = first_half.split('uvat')[0]
        patient_id.append(complete_name)
    #Set names in a column
    x_df['Patient # CDR, ADAS'] = patient_id
    x_df.pop('roi')
    
elif 'Unnamed: 0' in x_df.columns:
    print('unnamed detected')
    #Intialize conainter
    try:
        patient_id = []
        cols = []
        for name in x_df['Unnamed: 0'].values.tolist():
            try:
                patient_id.append(extract_digits(name)[0])
            except:
                print('No digits in name, returning -1')
                patient_id.append('10000')
        x_df['Unnamed: 0'] = patient_id
        x_df = x_df.reset_index(drop=True)
    except:
        raise Exception('Failed at Step 2, unable to identify column with patient IDs')
    x_df['Patient # CDR, ADAS'] = x_df['Unnamed: 0']
    x_df.pop('Unnamed: 0')

#Catch when an roi-roi correl is combined with the name
elif x_df.columns.values.tolist()[0][0:3] == 'sub':
    print('Sub detected')
    #Clean ROI Names
    patient_id = []
    for i in range(0, len(x_df.columns.values.tolist())):
        roi = x_df.columns.values.tolist()[i]
        basename = os.path.splitext(roi)[0]
        first_half = basename.split('sub-')[1]
        complete_name = first_half.split('uvat')[0]
        patient_id.append(complete_name)
    #Set names in a column
    x_df['Patient # CDR, ADAS'] = patient_id
    x_df = x_df.reset_index(drop=True)
    # x_df.pop('roi')
else:
    print('Failed to detect anything')
    patient_id = []
    try:
        try:
            patient_id.append(extract_digits(x_df.columns.values.tolist()))
        except:
            print('No digits in name, returning 10000')
            patient_id.append('10000')
        x_df['Patient # CDR, ADAS'] = patient_id
    except:
        x_df['Patient # CDR, ADAS'] = x_df.columns.values
        print('Could not manipulate')
                     
#Step 3) Sort by Patient ID
if sort:
    import natsort
    #Sort the columns
    natsorted_columns = natsort.natsorted(x_df.columns)
    x_df = x_df.reindex(columns=natsorted_columns)
    
    #Set patient ID as index and sort
    try:
        x_df = x_df.drop_duplicates(subset=['Patient # CDR, ADAS'])
        x_df = x_df.set_index('Patient # CDR, ADAS', drop=True)
        natsorted_index = natsort.natsorted(x_df.index)
    except:
        # x_df = x_df.drop_duplicates(subset=['Patient # CDR, ADAS'])
        natsorted_index = natsort.natsorted(x_df.index)
    x_df = x_df.reindex(index=natsorted_index)
else:
    x_df = x_df.set_index('Patient # CDR, ADAS', drop=True)
x_df.to_csv(conn_path.split('.csv')[0] + '_revised.csv')
display(x_df)
# Out:
# Failed to detect anything
# No digits in name, returning 10000
# Could not manipulate
#                            MDST01_seed_compound_fMRI  \
# Patient # CDR, ADAS
# MDST01_seed_compound_fMRI                        NaN
# MDST02_seed_compound_fMRI                 109.571458
# MDST04_seed_compound_fMRI                 103.404972
# MDST03_seed_compound_fMRI                 104.310198
# MDST06_seed_compound_fMRI                  85.688171
# MDST07_seed_compound_fMRI                  74.779218
# MDST09_seed_compound_fMRI                  84.928811
# MDST11_seed_compound_fMRI                  83.792620
# MDST12_seed_compound_fMRI                 108.589073
# MDST14_seed_compound_fMRI                 111.831722
# MDST15_seed_compound_fMRI                  58.725466
# MDST17_seed_compound_fMRI                  84.558161
# MDST19_seed_compound_fMRI                 102.727280
# MDST18_seed_compound_fMRI                 118.813043
# MDST21_seed_compound_fMRI                 177.816822
# MDST22_seed_compound_fMRI                  77.212454
# MDST23_seed_compound_fMRI                  99.698816
# MDST24_seed_compound_fMRI                  88.544440
# MDST26_seed_compound_fMRI                  84.272737
# MDST27_seed_compound_fMRI                  85.946957
# MDST28_seed_compound_fMRI                 102.677733
# MDST29_seed_compound_fMRI                  92.693363
# MDST30_seed_compound_fMRI                  80.954753
# MDST31_seed_compound_fMRI                 113.929750
# MDST33_seed_compound_fMRI                  65.705712
# MDST34_seed_compound_fMRI                  94.798299
# MDST36_seed_compound_fMRI                  64.117937
# MDST37_seed_compound_fMRI                 196.438785
# MDST38_seed_compound_fMRI                  66.202761
# MDST39_seed_compound_fMRI                 108.323090
# MDST43_seed_compound_fMRI                  91.028559
# MDST44_seed_compound_fMRI                 102.874886
# memory_roi                                 30.376565
#
#                            MDST02_seed_compound_fMRI  \
# Patient # CDR, ADAS
# MDST01_seed_compound_fMRI                 109.571458
# MDST02_seed_compound_fMRI                        NaN
# MDST04_seed_compound_fMRI                  93.284773
# MDST03_seed_compound_fMRI                 141.402385
# MDST06_seed_compound_fMRI                 131.229409
# MDST07_seed_compound_fMRI                  66.815075
# MDST09_seed_compound_fMRI                  92.861765
# MDST11_seed_compound_fMRI                 133.197514
# MDST12_seed_compound_fMRI                 138.898718
# MDST14_seed_compound_fMRI                 102.025537
# MDST15_seed_compound_fMRI                  48.290666
# MDST17_seed_compound_fMRI                 107.713587
# MDST19_seed_compound_fMRI                 136.369242
# MDST18_seed_compound_fMRI                 158.459632
# MDST21_seed_compound_fMRI                  82.852147
# MDST22_seed_compound_fMRI                 102.985364
# MDST23_seed_compound_fMRI                 197.832428
# MDST24_seed_compound_fMRI                 164.889888
# MDST26_seed_compound_fMRI                  80.981231
# MDST27_seed_compound_fMRI                 167.306872
# MDST28_seed_compound_fMRI                 112.985185
# MDST29_seed_compound_fMRI                  99.111610
# MDST30_seed_compound_fMRI                 136.222893
# MDST31_seed_compound_fMRI                 162.916648
# MDST33_seed_compound_fMRI                 150.702342
# MDST34_seed_compound_fMRI                  73.699656
# MDST36_seed_compound_fMRI                  79.458982
# MDST37_seed_compound_fMRI                 113.722834
# MDST38_seed_compound_fMRI                 137.784793
# MDST39_seed_compound_fMRI                 135.022364
# MDST43_seed_compound_fMRI                 264.738053
# MDST44_seed_compound_fMRI                 167.490427
# memory_roi                                 16.295870
#
#                            MDST04_seed_compound_fMRI  \
# Patient # CDR, ADAS
# MDST01_seed_compound_fMRI                 103.404972
# MDST02_seed_compound_fMRI                  93.284773
# MDST04_seed_compound_fMRI                        NaN
# MDST03_seed_compound_fMRI                  74.107998
# MDST06_seed_compound_fMRI                 106.988286
# MDST07_seed_compound_fMRI                  55.421347
# MDST09_seed_compound_fMRI                 236.344621
# MDST11_seed_compound_fMRI                 182.774445
# MDST12_seed_compound_fMRI                  84.278895
# MDST14_seed_compound_fMRI                 331.526852
# MDST15_seed_compound_fMRI                  67.578929
# MDST17_seed_compound_fMRI                  66.085468
# MDST19_seed_compound_fMRI                 111.917664
# MDST18_seed_compound_fMRI                 159.375745
# MDST21_seed_compound_fMRI                 151.069145
# MDST22_seed_compound_fMRI                 107.288018
# MDST23_seed_compound_fMRI                  94.359754
# MDST24_seed_compound_fMRI                  85.487932
# MDST26_seed_compound_fMRI                 119.567602
# MDST27_seed_compound_fMRI                 115.668941
# MDST28_seed_compound_fMRI                  68.206845
# MDST29_seed_compound_fMRI                  81.914573
# MDST30_seed_compound_fMRI                 120.571271
# MDST31_seed_compound_fMRI                 153.242056
# MDST33_seed_compound_fMRI                  82.206837
# MDST34_seed_compound_fMRI                  55.131205
# MDST36_seed_compound_fMRI                 200.795387
# MDST37_seed_compound_fMRI                 174.933814
# MDST38_seed_compound_fMRI                 126.215813
# MDST39_seed_compound_fMRI                 158.980499
# MDST43_seed_compound_fMRI                  83.084265
# MDST44_seed_compound_fMRI                  98.697114
# memory_roi                                 21.207602
#
#                            MDST03_seed_compound_fMRI  \
# Patient # CDR, ADAS
# MDST01_seed_compound_fMRI                 104.310198
# MDST02_seed_compound_fMRI                 141.402385
# MDST04_seed_compound_fMRI                  74.107998
# MDST03_seed_compound_fMRI                        NaN
# MDST06_seed_compound_fMRI                 183.418386
# MDST07_seed_compound_fMRI                 149.123859
# MDST09_seed_compound_fMRI                  67.680136
# MDST11_seed_compound_fMRI                 101.502387
# MDST12_seed_compound_fMRI                 201.095657
# MDST14_seed_compound_fMRI                  71.520772
# MDST15_seed_compound_fMRI                  75.716970
# MDST17_seed_compound_fMRI                 221.494206
# MDST19_seed_compound_fMRI                 188.151994
# MDST18_seed_compound_fMRI                  85.836446
# MDST21_seed_compound_fMRI                  77.830900
# MDST22_seed_compound_fMRI                 133.314876
# MDST23_seed_compound_fMRI                 119.342404
# MDST24_seed_compound_fMRI                 234.352145
# MDST26_seed_compound_fMRI                 123.021134
# MDST27_seed_compound_fMRI                 157.661906
# MDST28_seed_compound_fMRI                 282.495567
# MDST29_seed_compound_fMRI                 199.778352
# MDST30_seed_compound_fMRI                 149.600676
# MDST31_seed_compound_fMRI                 109.287179
# MDST33_seed_compound_fMRI                  87.728883
# MDST34_seed_compound_fMRI                 189.457848
# MDST36_seed_compound_fMRI                  59.966315
# MDST37_seed_compound_fMRI                  65.715802
# MDST38_seed_compound_fMRI                  83.173913
# MDST39_seed_compound_fMRI                 125.682186
# MDST43_seed_compound_fMRI                 154.050788
# MDST44_seed_compound_fMRI                 110.556482
# memory_roi                                 30.900051
#
#                            MDST06_seed_compound_fMRI  \
# Patient # CDR, ADAS
# MDST01_seed_compound_fMRI                  85.688171
# MDST02_seed_compound_fMRI                 131.229409
# MDST04_seed_compound_fMRI                 106.988286
# MDST03_seed_compound_fMRI                 183.418386
# MDST06_seed_compound_fMRI                        NaN
# MDST07_seed_compound_fMRI                 129.345440
# MDST09_seed_compound_fMRI                  87.382192
# MDST11_seed_compound_fMRI                 168.076895
# MDST12_seed_compound_fMRI                 156.947427
# MDST14_seed_compound_fMRI                 102.188115
# MDST15_seed_compound_fMRI                  75.818872
# MDST17_seed_compound_fMRI                 181.835309
# MDST19_seed_compound_fMRI                 200.714184
# MDST18_seed_compound_fMRI                 116.352252
# MDST21_seed_compound_fMRI                  93.290731
# MDST22_seed_compound_fMRI                 234.134156
# MDST23_seed_compound_fMRI                 117.861476
# MDST24_seed_compound_fMRI                 209.089132
# MDST26_seed_compound_fMRI                 181.938427
# MDST27_seed_compound_fMRI                 233.319574
# MDST28_seed_compound_fMRI                 172.545456
# MDST29_seed_compound_fMRI                 189.100216
# MDST30_seed_compound_fMRI                 236.152828
# MDST31_seed_compound_fMRI                 141.762826
# MDST33_seed_compound_fMRI                 109.651244
# MDST34_seed_compound_fMRI                 134.140080
# MDST36_seed_compound_fMRI                  96.181753
# MDST37_seed_compound_fMRI                  83.993924
# MDST38_seed_compound_fMRI                 114.140448
# MDST39_seed_compound_fMRI                 180.171066
# MDST43_seed_compound_fMRI                 147.395512
# MDST44_seed_compound_fMRI                  97.706138
# memory_roi                                 23.577739
#
#                            MDST07_seed_compound_fMRI  \
# Patient # CDR, ADAS
# MDST01_seed_compound_fMRI                  74.779218
# MDST02_seed_compound_fMRI                  66.815075
# MDST04_seed_compound_fMRI                  55.421347
# MDST03_seed_compound_fMRI                 149.123859
# MDST06_seed_compound_fMRI                 129.345440
# MDST07_seed_compound_fMRI                        NaN
# MDST09_seed_compound_fMRI                  46.152289
# MDST11_seed_compound_fMRI                  63.226682
# MDST12_seed_compound_fMRI                 168.869863
# MDST14_seed_compound_fMRI                  49.106795
# MDST15_seed_compound_fMRI                  98.696423
# MDST17_seed_compound_fMRI                 180.402254
# MDST19_seed_compound_fMRI                 122.072803
# MDST18_seed_compound_fMRI                  57.392064
# MDST21_seed_compound_fMRI                  73.118425
# MDST22_seed_compound_fMRI                  90.909846
# MDST23_seed_compound_fMRI                  60.073430
# MDST24_seed_compound_fMRI                 143.344458
# MDST26_seed_compound_fMRI                 115.210259
# MDST27_seed_compound_fMRI                  94.439573
# MDST28_seed_compound_fMRI                 133.017282
# MDST29_seed_compound_fMRI                 146.246123
# MDST30_seed_compound_fMRI                  86.467282
# MDST31_seed_compound_fMRI                  61.488303
# MDST33_seed_compound_fMRI                  42.471611
# MDST34_seed_compound_fMRI                 140.803184
# MDST36_seed_compound_fMRI                  44.839366
# MDST37_seed_compound_fMRI                  44.482297
# MDST38_seed_compound_fMRI                  44.966310
# MDST39_seed_compound_fMRI                 102.877347
# MDST43_seed_compound_fMRI                  93.435590
# MDST44_seed_compound_fMRI                  57.634938
# memory_roi                                 36.657479
#
#                            MDST09_seed_compound_fMRI  \
# Patient # CDR, ADAS
# MDST01_seed_compound_fMRI                  84.928811
# MDST02_seed_compound_fMRI                  92.861765
# MDST04_seed_compound_fMRI                 236.344621
# MDST03_seed_compound_fMRI                  67.680136
# MDST06_seed_compound_fMRI                  87.382192
# MDST07_seed_compound_fMRI                  46.152289
# MDST09_seed_compound_fMRI                        NaN
# MDST11_seed_compound_fMRI                 143.120197
# MDST12_seed_compound_fMRI                  71.093741
# MDST14_seed_compound_fMRI                 273.596130
# MDST15_seed_compound_fMRI                  53.451351
# MDST17_seed_compound_fMRI                  55.290178
# MDST19_seed_compound_fMRI                  84.562305
# MDST18_seed_compound_fMRI                 136.546864
# MDST21_seed_compound_fMRI                  99.479323
# MDST22_seed_compound_fMRI                  78.197276
# MDST23_seed_compound_fMRI                  91.709288
# MDST24_seed_compound_fMRI                  75.450576
# MDST26_seed_compound_fMRI                  78.751554
# MDST27_seed_compound_fMRI                  91.106163
# MDST28_seed_compound_fMRI                  59.237130
# MDST29_seed_compound_fMRI                  63.031987
# MDST30_seed_compound_fMRI                  92.728378
# MDST31_seed_compound_fMRI                 121.559864
# MDST33_seed_compound_fMRI                  77.082468
# MDST34_seed_compound_fMRI                  41.582637
# MDST36_seed_compound_fMRI                 158.791726
# MDST37_seed_compound_fMRI                 144.629757
# MDST38_seed_compound_fMRI                 113.223933
# MDST39_seed_compound_fMRI                 119.126932
# MDST43_seed_compound_fMRI                  77.136465
# MDST44_seed_compound_fMRI                 114.534658
# memory_roi                                 19.955774
#
#                            MDST11_seed_compound_fMRI  \
# Patient # CDR, ADAS
# MDST01_seed_compound_fMRI                  83.792620
# MDST02_seed_compound_fMRI                 133.197514
# MDST04_seed_compound_fMRI                 182.774445
# MDST03_seed_compound_fMRI                 101.502387
# MDST06_seed_compound_fMRI                 168.076895
# MDST07_seed_compound_fMRI                  63.226682
# MDST09_seed_compound_fMRI                 143.120197
# MDST11_seed_compound_fMRI                        NaN
# MDST12_seed_compound_fMRI                 101.720565
# MDST14_seed_compound_fMRI                 185.672174
# MDST15_seed_compound_fMRI                  58.118861
# MDST17_seed_compound_fMRI                  86.347574
# MDST19_seed_compound_fMRI                 136.713160
# MDST18_seed_compound_fMRI                 173.810556
# MDST21_seed_compound_fMRI                 102.860478
# MDST22_seed_compound_fMRI                 170.232781
# MDST23_seed_compound_fMRI                 129.926656
# MDST24_seed_compound_fMRI                 126.505869
# MDST26_seed_compound_fMRI                 146.572443
# MDST27_seed_compound_fMRI                 179.924366
# MDST28_seed_compound_fMRI                  94.133342
# MDST29_seed_compound_fMRI                 108.496530
# MDST30_seed_compound_fMRI                 191.536432
# MDST31_seed_compound_fMRI                 192.735132
# MDST33_seed_compound_fMRI                 125.176990
# MDST34_seed_compound_fMRI                  65.616853
# MDST36_seed_compound_fMRI                 183.581618
# MDST37_seed_compound_fMRI                 131.582614
# MDST38_seed_compound_fMRI                 184.719664
# MDST39_seed_compound_fMRI                 201.002403
# MDST43_seed_compound_fMRI                 124.750969
# MDST44_seed_compound_fMRI                 114.905859
# memory_roi                                 15.156220
#
#                            MDST12_seed_compound_fMRI  \
# Patient # CDR, ADAS
# MDST01_seed_compound_fMRI                 108.589073
# MDST02_seed_compound_fMRI                 138.898718
# MDST04_seed_compound_fMRI                  84.278895
# MDST03_seed_compound_fMRI                 201.095657
# MDST06_seed_compound_fMRI                 156.947427
# MDST07_seed_compound_fMRI                 168.869863
# MDST09_seed_compound_fMRI                  71.093741
# MDST11_seed_compound_fMRI                 101.720565
# MDST12_seed_compound_fMRI                        NaN
# MDST14_seed_compound_fMRI                  80.485592
# MDST15_seed_compound_fMRI                  85.981917
# MDST17_seed_compound_fMRI                 187.118952
# MDST19_seed_compound_fMRI                 193.483670
# MDST18_seed_compound_fMRI                 108.338548
# MDST21_seed_compound_fMRI                 110.120522
# MDST22_seed_compound_fMRI                 110.566493
# MDST23_seed_compound_fMRI                 134.352788
# MDST24_seed_compound_fMRI                 211.504994
# MDST26_seed_compound_fMRI                 124.082902
# MDST27_seed_compound_fMRI                 141.468866
# MDST28_seed_compound_fMRI                 146.000951
# MDST29_seed_compound_fMRI                 159.450691
# MDST30_seed_compound_fMRI                 123.906017
# MDST31_seed_compound_fMRI                 108.511868
# MDST33_seed_compound_fMRI                  70.369501
# MDST34_seed_compound_fMRI                 133.298653
# MDST36_seed_compound_fMRI                  62.371089
# MDST37_seed_compound_fMRI                  85.174051
# MDST38_seed_compound_fMRI                  75.351770
# MDST39_seed_compound_fMRI                 159.750798
# MDST43_seed_compound_fMRI                 158.227758
# MDST44_seed_compound_fMRI                 132.589496
# memory_roi                                 28.328345
#
#                            MDST14_seed_compound_fMRI  ...  \
# Patient # CDR, ADAS                                   ...
# MDST01_seed_compound_fMRI                 111.831722  ...
# MDST02_seed_compound_fMRI                 102.025537  ...
# MDST04_seed_compound_fMRI                 331.526852  ...
# MDST03_seed_compound_fMRI                  71.520772  ...
# MDST06_seed_compound_fMRI                 102.188115  ...
# MDST07_seed_compound_fMRI                  49.106795  ...
# MDST09_seed_compound_fMRI                 273.596130  ...
# MDST11_seed_compound_fMRI                 185.672174  ...
# MDST12_seed_compound_fMRI                  80.485592  ...
# MDST14_seed_compound_fMRI                        NaN  ...
# MDST15_seed_compound_fMRI                  56.569447  ...
# MDST17_seed_compound_fMRI                  60.121348  ...
# MDST19_seed_compound_fMRI                  99.314964  ...
# MDST18_seed_compound_fMRI                 178.470437  ...
# MDST21_seed_compound_fMRI                 142.277911  ...
# MDST22_seed_compound_fMRI                  97.026855  ...
# MDST23_seed_compound_fMRI                 104.348916  ...
# MDST24_seed_compound_fMRI                  82.426387  ...
# MDST26_seed_compound_fMRI                 101.164345  ...
# MDST27_seed_compound_fMRI                 106.598302  ...
# MDST28_seed_compound_fMRI                  63.595276  ...
# MDST29_seed_compound_fMRI                  71.247939  ...
# MDST30_seed_compound_fMRI                 110.725493  ...
# MDST31_seed_compound_fMRI                 148.475493  ...
# MDST33_seed_compound_fMRI                  86.327345  ...
# MDST34_seed_compound_fMRI                  46.996398  ...
# MDST36_seed_compound_fMRI                 199.271917  ...
# MDST37_seed_compound_fMRI                 203.991649  ...
# MDST38_seed_compound_fMRI                 125.959530  ...
# MDST39_seed_compound_fMRI                 166.044216  ...
# MDST43_seed_compound_fMRI                  86.039666  ...
# MDST44_seed_compound_fMRI                 114.925087  ...
# memory_roi                                 19.619016  ...
#
#                            MDST31_seed_compound_fMRI  \
# Patient # CDR, ADAS
# MDST01_seed_compound_fMRI                 113.929750
# MDST02_seed_compound_fMRI                 162.916648
# MDST04_seed_compound_fMRI                 153.242056
# MDST03_seed_compound_fMRI                 109.287179
# MDST06_seed_compound_fMRI                 141.762826
# MDST07_seed_compound_fMRI                  61.488303
# MDST09_seed_compound_fMRI                 121.559864
# MDST11_seed_compound_fMRI                 192.735132
# MDST12_seed_compound_fMRI                 108.511868
# MDST14_seed_compound_fMRI                 148.475493
# MDST15_seed_compound_fMRI                  58.003509
# MDST17_seed_compound_fMRI                  91.678874
# MDST19_seed_compound_fMRI                 171.150031
# MDST18_seed_compound_fMRI                 150.017806
# MDST21_seed_compound_fMRI                 112.405399
# MDST22_seed_compound_fMRI                 156.639293
# MDST23_seed_compound_fMRI                 148.521252
# MDST24_seed_compound_fMRI                 124.249577
# MDST26_seed_compound_fMRI                 141.578741
# MDST27_seed_compound_fMRI                 175.650274
# MDST28_seed_compound_fMRI                 102.829171
# MDST29_seed_compound_fMRI                 122.911084
# MDST30_seed_compound_fMRI                 193.876827
# MDST31_seed_compound_fMRI                        NaN
# MDST33_seed_compound_fMRI                 142.725369
# MDST34_seed_compound_fMRI                  82.578755
# MDST36_seed_compound_fMRI                 129.890944
# MDST37_seed_compound_fMRI                 140.906109
# MDST38_seed_compound_fMRI                 195.877141
# MDST39_seed_compound_fMRI                 138.818591
# MDST43_seed_compound_fMRI                 130.861096
# MDST44_seed_compound_fMRI                 132.255439
# memory_roi                                 15.353030
#
#                            MDST33_seed_compound_fMRI  \
# Patient # CDR, ADAS
# MDST01_seed_compound_fMRI                  65.705712
# MDST02_seed_compound_fMRI                 150.702342
# MDST04_seed_compound_fMRI                  82.206837
# MDST03_seed_compound_fMRI                  87.728883
# MDST06_seed_compound_fMRI                 109.651244
# MDST07_seed_compound_fMRI                  42.471611
# MDST09_seed_compound_fMRI                  77.082468
# MDST11_seed_compound_fMRI                 125.176990
# MDST12_seed_compound_fMRI                  70.369501
# MDST14_seed_compound_fMRI                  86.327345
# MDST15_seed_compound_fMRI                  37.467211
# MDST17_seed_compound_fMRI                  70.086562
# MDST19_seed_compound_fMRI                  89.448426
# MDST18_seed_compound_fMRI                  85.926841
# MDST21_seed_compound_fMRI                  56.216479
# MDST22_seed_compound_fMRI                 116.529233
# MDST23_seed_compound_fMRI                 183.839440
# MDST24_seed_compound_fMRI                  94.174511
# MDST26_seed_compound_fMRI                  68.157129
# MDST27_seed_compound_fMRI                 122.937583
# MDST28_seed_compound_fMRI                  84.592518
# MDST29_seed_compound_fMRI                  76.157244
# MDST30_seed_compound_fMRI                 145.974824
# MDST31_seed_compound_fMRI                 142.725369
# MDST33_seed_compound_fMRI                        NaN
# MDST34_seed_compound_fMRI                  57.643753
# MDST36_seed_compound_fMRI                 106.536792
# MDST37_seed_compound_fMRI                  74.542711
# MDST38_seed_compound_fMRI                 185.906880
# MDST39_seed_compound_fMRI                  80.176279
# MDST43_seed_compound_fMRI                 157.191037
# MDST44_seed_compound_fMRI                 105.229963
# memory_roi                                 15.050219
#
#                            MDST34_seed_compound_fMRI  \
# Patient # CDR, ADAS
# MDST01_seed_compound_fMRI                  94.798299
# MDST02_seed_compound_fMRI                  73.699656
# MDST04_seed_compound_fMRI                  55.131205
# MDST03_seed_compound_fMRI                 189.457848
# MDST06_seed_compound_fMRI                 134.140080
# MDST07_seed_compound_fMRI                 140.803184
# MDST09_seed_compound_fMRI                  41.582637
# MDST11_seed_compound_fMRI                  65.616853
# MDST12_seed_compound_fMRI                 133.298653
# MDST14_seed_compound_fMRI                  46.996398
# MDST15_seed_compound_fMRI                  81.297149
# MDST17_seed_compound_fMRI                 177.285267
# MDST19_seed_compound_fMRI                 153.406033
# MDST18_seed_compound_fMRI                  54.779576
# MDST21_seed_compound_fMRI                  75.872126
# MDST22_seed_compound_fMRI                 131.607664
# MDST23_seed_compound_fMRI                  55.621238
# MDST24_seed_compound_fMRI                 128.983504
# MDST26_seed_compound_fMRI                 145.188613
# MDST27_seed_compound_fMRI                 118.327035
# MDST28_seed_compound_fMRI                 259.475619
# MDST29_seed_compound_fMRI                 225.944222
# MDST30_seed_compound_fMRI                 119.499560
# MDST31_seed_compound_fMRI                  82.578755
# MDST33_seed_compound_fMRI                  57.643753
# MDST34_seed_compound_fMRI                        NaN
# MDST36_seed_compound_fMRI                  51.804942
# MDST37_seed_compound_fMRI                  42.603116
# MDST38_seed_compound_fMRI                  54.379488
# MDST39_seed_compound_fMRI                  80.200568
# MDST43_seed_compound_fMRI                  90.340285
# MDST44_seed_compound_fMRI                  42.747091
# memory_roi                                 34.047011
#
#                            MDST36_seed_compound_fMRI  \
# Patient # CDR, ADAS
# MDST01_seed_compound_fMRI                  64.117937
# MDST02_seed_compound_fMRI                  79.458982
# MDST04_seed_compound_fMRI                 200.795387
# MDST03_seed_compound_fMRI                  59.966315
# MDST06_seed_compound_fMRI                  96.181753
# MDST07_seed_compound_fMRI                  44.839366
# MDST09_seed_compound_fMRI                 158.791726
# MDST11_seed_compound_fMRI                 183.581618
# MDST12_seed_compound_fMRI                  62.371089
# MDST14_seed_compound_fMRI                 199.271917
# MDST15_seed_compound_fMRI                  50.486077
# MDST17_seed_compound_fMRI                  57.812138
# MDST19_seed_compound_fMRI                  87.914365
# MDST18_seed_compound_fMRI                 113.217550
# MDST21_seed_compound_fMRI                  90.502170
# MDST22_seed_compound_fMRI                 119.742152
# MDST23_seed_compound_fMRI                  92.368027
# MDST24_seed_compound_fMRI                  71.227987
# MDST26_seed_compound_fMRI                 101.116170
# MDST27_seed_compound_fMRI                 110.028955
# MDST28_seed_compound_fMRI                  60.812692
# MDST29_seed_compound_fMRI                  70.681675
# MDST30_seed_compound_fMRI                 125.105226
# MDST31_seed_compound_fMRI                 129.890944
# MDST33_seed_compound_fMRI                 106.536792
# MDST34_seed_compound_fMRI                  51.804942
# MDST36_seed_compound_fMRI                        NaN
# MDST37_seed_compound_fMRI                 114.528736
# MDST38_seed_compound_fMRI                 154.060848
# MDST39_seed_compound_fMRI                 109.703862
# MDST43_seed_compound_fMRI                  83.233075
# MDST44_seed_compound_fMRI                  85.055676
# memory_roi                                 17.382020
#
#                            MDST37_seed_compound_fMRI  \
# Patient # CDR, ADAS
# MDST01_seed_compound_fMRI                 196.438785
# MDST02_seed_compound_fMRI                 113.722834
# MDST04_seed_compound_fMRI                 174.933814
# MDST03_seed_compound_fMRI                  65.715802
# MDST06_seed_compound_fMRI                  83.993924
# MDST07_seed_compound_fMRI                  44.482297
# MDST09_seed_compound_fMRI                 144.629757
# MDST11_seed_compound_fMRI                 131.582614
# MDST12_seed_compound_fMRI                  85.174051
# MDST14_seed_compound_fMRI                 203.991649
# MDST15_seed_compound_fMRI                  49.027660
# MDST17_seed_compound_fMRI                  56.145473
# MDST19_seed_compound_fMRI                  95.495236
# MDST18_seed_compound_fMRI                 195.995707
# MDST21_seed_compound_fMRI                 190.990553
# MDST22_seed_compound_fMRI                  77.913394
# MDST23_seed_compound_fMRI                 113.584119
# MDST24_seed_compound_fMRI                  76.448013
# MDST26_seed_compound_fMRI                  83.619157
# MDST27_seed_compound_fMRI                  94.844263
# MDST28_seed_compound_fMRI                  55.423809
# MDST29_seed_compound_fMRI                  62.514354
# MDST30_seed_compound_fMRI                  87.874506
# MDST31_seed_compound_fMRI                 140.906109
# MDST33_seed_compound_fMRI                  74.542711
# MDST34_seed_compound_fMRI                  42.603116
# MDST36_seed_compound_fMRI                 114.528736
# MDST37_seed_compound_fMRI                        NaN
# MDST38_seed_compound_fMRI                  97.108643
# MDST39_seed_compound_fMRI                 143.319189
# MDST43_seed_compound_fMRI                  87.604394
# MDST44_seed_compound_fMRI                 125.912765
# memory_roi                                 17.978233
#
#                            MDST38_seed_compound_fMRI  \
# Patient # CDR, ADAS
# MDST01_seed_compound_fMRI                  66.202761
# MDST02_seed_compound_fMRI                 137.784793
# MDST04_seed_compound_fMRI                 126.215813
# MDST03_seed_compound_fMRI                  83.173913
# MDST06_seed_compound_fMRI                 114.140448
# MDST07_seed_compound_fMRI                  44.966310
# MDST09_seed_compound_fMRI                 113.223933
# MDST11_seed_compound_fMRI                 184.719664
# MDST12_seed_compound_fMRI                  75.351770
# MDST14_seed_compound_fMRI                 125.959530
# MDST15_seed_compound_fMRI                  48.002387
# MDST17_seed_compound_fMRI                  68.196696
# MDST19_seed_compound_fMRI                 105.965676
# MDST18_seed_compound_fMRI                 117.440982
# MDST21_seed_compound_fMRI                  72.181726
# MDST22_seed_compound_fMRI                 124.830667
# MDST23_seed_compound_fMRI                 137.310706
# MDST24_seed_compound_fMRI                  99.030483
# MDST26_seed_compound_fMRI                  90.995619
# MDST27_seed_compound_fMRI                 147.499474
# MDST28_seed_compound_fMRI                  80.938307
# MDST29_seed_compound_fMRI                  87.991085
# MDST30_seed_compound_fMRI                 169.883661
# MDST31_seed_compound_fMRI                 195.877141
# MDST33_seed_compound_fMRI                 185.906880
# MDST34_seed_compound_fMRI                  54.379488
# MDST36_seed_compound_fMRI                 154.060848
# MDST37_seed_compound_fMRI                  97.108643
# MDST38_seed_compound_fMRI                        NaN
# MDST39_seed_compound_fMRI                 102.751061
# MDST43_seed_compound_fMRI                 127.277955
# MDST44_seed_compound_fMRI                 112.063081
# memory_roi                                 14.611144
#
#                            MDST39_seed_compound_fMRI  \
# Patient # CDR, ADAS
# MDST01_seed_compound_fMRI                 108.323090
# MDST02_seed_compound_fMRI                 135.022364
# MDST04_seed_compound_fMRI                 158.980499
# MDST03_seed_compound_fMRI                 125.682186
# MDST06_seed_compound_fMRI                 180.171066
# MDST07_seed_compound_fMRI                 102.877347
# MDST09_seed_compound_fMRI                 119.126932
# MDST11_seed_compound_fMRI                 201.002403
# MDST12_seed_compound_fMRI                 159.750798
# MDST14_seed_compound_fMRI                 166.044216
# MDST15_seed_compound_fMRI                  73.468415
# MDST17_seed_compound_fMRI                 110.751942
# MDST19_seed_compound_fMRI                 159.423849
# MDST18_seed_compound_fMRI                 203.367166
# MDST21_seed_compound_fMRI                 137.845083
# MDST22_seed_compound_fMRI                 128.427412
# MDST23_seed_compound_fMRI                 123.882985
# MDST24_seed_compound_fMRI                 151.530505
# MDST26_seed_compound_fMRI                 155.849049
# MDST27_seed_compound_fMRI                 151.546894
# MDST28_seed_compound_fMRI                 101.861595
# MDST29_seed_compound_fMRI                 117.314111
# MDST30_seed_compound_fMRI                 136.357993
# MDST31_seed_compound_fMRI                 138.818591
# MDST33_seed_compound_fMRI                  80.176279
# MDST34_seed_compound_fMRI                  80.200568
# MDST36_seed_compound_fMRI                 109.703862
# MDST37_seed_compound_fMRI                 143.319189
# MDST38_seed_compound_fMRI                 102.751061
# MDST39_seed_compound_fMRI                        NaN
# MDST43_seed_compound_fMRI                 130.893306
# MDST44_seed_compound_fMRI                 119.195477
# memory_roi                                 21.551613
#
#                            MDST43_seed_compound_fMRI  \
# Patient # CDR, ADAS
# MDST01_seed_compound_fMRI                  91.028559
# MDST02_seed_compound_fMRI                 264.738053
# MDST04_seed_compound_fMRI                  83.084265
# MDST03_seed_compound_fMRI                 154.050788
# MDST06_seed_compound_fMRI                 147.395512
# MDST07_seed_compound_fMRI                  93.435590
# MDST09_seed_compound_fMRI                  77.136465
# MDST11_seed_compound_fMRI                 124.750969
# MDST12_seed_compound_fMRI                 158.227758
# MDST14_seed_compound_fMRI                  86.039666
# MDST15_seed_compound_fMRI                  58.592295
# MDST17_seed_compound_fMRI                 139.313582
# MDST19_seed_compound_fMRI                 141.601583
# MDST18_seed_compound_fMRI                 132.292015
# MDST21_seed_compound_fMRI                  75.113879
# MDST22_seed_compound_fMRI                 115.015353
# MDST23_seed_compound_fMRI                 165.460411
# MDST24_seed_compound_fMRI                 187.409325
# MDST26_seed_compound_fMRI                  89.603428
# MDST27_seed_compound_fMRI                 187.029215
# MDST28_seed_compound_fMRI                 125.238847
# MDST29_seed_compound_fMRI                 110.772315
# MDST30_seed_compound_fMRI                 146.497648
# MDST31_seed_compound_fMRI                 130.861096
# MDST33_seed_compound_fMRI                 157.191037
# MDST34_seed_compound_fMRI                  90.340285
# MDST36_seed_compound_fMRI                  83.233075
# MDST37_seed_compound_fMRI                  87.604394
# MDST38_seed_compound_fMRI                 127.277955
# MDST39_seed_compound_fMRI                 130.893306
# MDST43_seed_compound_fMRI                        NaN
# MDST44_seed_compound_fMRI                 120.868303
# memory_roi                                 20.200341
#
#                            MDST44_seed_compound_fMRI  memory_roi
# Patient # CDR, ADAS
# MDST01_seed_compound_fMRI                 102.874886   30.376565
# MDST02_seed_compound_fMRI                 167.490427   16.295870
# MDST04_seed_compound_fMRI                  98.697114   21.207602
# MDST03_seed_compound_fMRI                 110.556482   30.900051
# MDST06_seed_compound_fMRI                  97.706138   23.577739
# MDST07_seed_compound_fMRI                  57.634938   36.657479
# MDST09_seed_compound_fMRI                 114.534658   19.955774
# MDST11_seed_compound_fMRI                 114.905859   15.156220
# MDST12_seed_compound_fMRI                 132.589496   28.328345
# MDST14_seed_compound_fMRI                 114.925087   19.619016
# MDST15_seed_compound_fMRI                  37.809573   39.316089
# MDST17_seed_compound_fMRI                  86.986090   30.014730
# MDST19_seed_compound_fMRI                 109.777789   23.128431
# MDST18_seed_compound_fMRI                 126.531154   15.781874
# MDST21_seed_compound_fMRI                  84.385279   26.016428
# MDST22_seed_compound_fMRI                  70.835819   19.953155
# MDST23_seed_compound_fMRI                 244.702118   15.519790
# MDST24_seed_compound_fMRI                 132.173668   24.237392
# MDST26_seed_compound_fMRI                  59.130700   24.468157
# MDST27_seed_compound_fMRI                 101.139289   18.800226
# MDST28_seed_compound_fMRI                  74.077189   32.297293
# MDST29_seed_compound_fMRI                  68.859780   29.015201
# MDST30_seed_compound_fMRI                  97.450064   18.674670
# MDST31_seed_compound_fMRI                 132.255439   15.353030
# MDST33_seed_compound_fMRI                 105.229963   15.050219
# MDST34_seed_compound_fMRI                  42.747091   34.047011
# MDST36_seed_compound_fMRI                  85.055676   17.382020
# MDST37_seed_compound_fMRI                 125.912765   17.978233
# MDST38_seed_compound_fMRI                 112.063081   14.611144
# MDST39_seed_compound_fMRI                 119.195477   21.551613
# MDST43_seed_compound_fMRI                 120.868303   20.200341
# MDST44_seed_compound_fMRI                        NaN   14.468351
# memory_roi                                 14.468351         NaN
#
# [33 rows x 33 columns]

# %%
# import pandas as pd

# new_df = pd.DataFrame(index=x_df.index, columns=x_df.columns[::2])
# for i in range(0, x_df.shape[1]//2):
#     new_df.iloc[:, i] = x_df.iloc[:, i*2]

# new_df.dropna(axis=1, how='all', inplace=True)
# new_df

import pandas as pd
new_df = x_df.copy()
new_df.set_index(['Unnamed: 0'], inplace=True)
fresh_dict = {}
for name in new_df.index:
    id = name.split('_')[0]
    if name.split('_')[1][0:3] == 'vat':
        fresh_dict[id] = new_df.loc[name, f'{id}_generated_nifti.nii']
corr_df = pd.DataFrame(fresh_dict, index=['spatial_correlation']).transpose()
corr_df['Patient # CDR, ADAS'] = corr_df.index
# corr_df['Patient # CDR, ADAS'] = corr_df.index.co
display(corr_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 12
#      10 import pandas as pd
#      11 new_df = x_df.copy()
# ---> 12 new_df.set_index(['Unnamed: 0'], inplace=True)
#      13 fresh_dict = {}
#      14 for name in new_df.index:
#
# File /usr/local/Caskroom/mambaforge/base/envs/nimlab_py310/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /usr/local/Caskroom/mambaforge/base/envs/nimlab_py310/lib/python3.10/site-packages/pandas/core/frame.py:6009, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    6006                 missing.append(col)
#    6008 if missing:
# -> 6009     raise KeyError(f"None of {missing} are in the columns")
#    6011 if inplace:
#    6012     frame = self
#
# KeyError: "None of ['Unnamed: 0'] are in the columns"

# %%
# new_df = pd.DataFrame()
# new_df = pd.DataFrame(np.nan, index=np.arange(50), columns=['Spatial Correlation'])
# new_df.set_index(x_df.index, inplace=True)
# new_df.shape
# for i in range(0, x_df.shape[0]):
#     new_df.iloc[i, 0] = x_df.iloc[i, i*2]
# new_df
# new_df.to_csv(os.path.join('/Users/cu135/Dropbox (Partners HealthCare)/resources/datasets/BIDS_AD_DBS_FORNIX/clinical_data', 'new_df.csv'))

# %% [markdown]
# Visualize the dataframe above and create a new dataframe with only the relevant rows and columns.

# %%
# Define columns to keep
cols_of_interest = pd.IndexSlice['memory_roi']

# Define rows to keep
rows_of_interest = pd.IndexSlice['103_vat_seed_compound_fMRI_efield':'101_vat_seed_compound_fMRI_efield']

###----------------------------------------------------------------USER INPUT----------------------------------------------------------------
t_df = x_df.copy()

# Include Rows
# cols_of_interest = t_df.columns.difference(cols_of_disinterest)

# Remove cols_of_disinterest from corr_df
# t_df.set_index('Unnamed: 0', inplace=True)
t_df = t_df.iloc[:50, :]
corr_df = t_df.loc[:, [cols_of_interest]]
# corr_df = t_df.iloc[1:, 0]
# corr_df = corr_df.rename(columns={'sub-ADAS11uAD1uverifyuvoxutstatufwep_space-2mm_lesionMask_T': 'Connectivity to ADAS Cog-11 ROI'})
corr_df.to_csv(conn_path.split('.csv')[0] + 'revised_connection_of_interest.csv')
# corr_df.rename(columns={cols_of_interest[0]: 'ADAS-Cog 11 Map'}, inplace=True)
# corr_df.reset_index(inplace=True)
display(corr_df)
# Out:
#                            memory_roi
# Patient # CDR, ADAS
# MDST01_seed_compound_fMRI   30.376565
# MDST02_seed_compound_fMRI   16.295870
# MDST04_seed_compound_fMRI   21.207602
# MDST03_seed_compound_fMRI   30.900051
# MDST06_seed_compound_fMRI   23.577739
# MDST07_seed_compound_fMRI   36.657479
# MDST09_seed_compound_fMRI   19.955774
# MDST11_seed_compound_fMRI   15.156220
# MDST12_seed_compound_fMRI   28.328345
# MDST14_seed_compound_fMRI   19.619016
# MDST15_seed_compound_fMRI   39.316089
# MDST17_seed_compound_fMRI   30.014730
# MDST19_seed_compound_fMRI   23.128431
# MDST18_seed_compound_fMRI   15.781874
# MDST21_seed_compound_fMRI   26.016428
# MDST22_seed_compound_fMRI   19.953155
# MDST23_seed_compound_fMRI   15.519790
# MDST24_seed_compound_fMRI   24.237392
# MDST26_seed_compound_fMRI   24.468157
# MDST27_seed_compound_fMRI   18.800226
# MDST28_seed_compound_fMRI   32.297293
# MDST29_seed_compound_fMRI   29.015201
# MDST30_seed_compound_fMRI   18.674670
# MDST31_seed_compound_fMRI   15.353030
# MDST33_seed_compound_fMRI   15.050219
# MDST34_seed_compound_fMRI   34.047011
# MDST36_seed_compound_fMRI   17.382020
# MDST37_seed_compound_fMRI   17.978233
# MDST38_seed_compound_fMRI   14.611144
# MDST39_seed_compound_fMRI   21.551613
# MDST43_seed_compound_fMRI   20.200341
# MDST44_seed_compound_fMRI   14.468351
# memory_roi                        NaN

# %%
##--emergency code--#
# names=[]
# for name in corr_df['Patient # CDR, ADAS'].values.tolist():
#     names.append(extract_digits(name)[0])
# corr_df['Patient # CDR, ADAS'] = names
# corr_df.pop('index')
# x_df = x_df.set_index('Patient # CDR, ADAS')
display(corr_df)
# Out:
#                            memory_roi
# Patient # CDR, ADAS
# MDST01_seed_compound_fMRI   30.376565
# MDST02_seed_compound_fMRI   16.295870
# MDST04_seed_compound_fMRI   21.207602
# MDST03_seed_compound_fMRI   30.900051
# MDST06_seed_compound_fMRI   23.577739
# MDST07_seed_compound_fMRI   36.657479
# MDST09_seed_compound_fMRI   19.955774
# MDST11_seed_compound_fMRI   15.156220
# MDST12_seed_compound_fMRI   28.328345
# MDST14_seed_compound_fMRI   19.619016
# MDST15_seed_compound_fMRI   39.316089
# MDST17_seed_compound_fMRI   30.014730
# MDST19_seed_compound_fMRI   23.128431
# MDST18_seed_compound_fMRI   15.781874
# MDST21_seed_compound_fMRI   26.016428
# MDST22_seed_compound_fMRI   19.953155
# MDST23_seed_compound_fMRI   15.519790
# MDST24_seed_compound_fMRI   24.237392
# MDST26_seed_compound_fMRI   24.468157
# MDST27_seed_compound_fMRI   18.800226
# MDST28_seed_compound_fMRI   32.297293
# MDST29_seed_compound_fMRI   29.015201
# MDST30_seed_compound_fMRI   18.674670
# MDST31_seed_compound_fMRI   15.353030
# MDST33_seed_compound_fMRI   15.050219
# MDST34_seed_compound_fMRI   34.047011
# MDST36_seed_compound_fMRI   17.382020
# MDST37_seed_compound_fMRI   17.978233
# MDST38_seed_compound_fMRI   14.611144
# MDST39_seed_compound_fMRI   21.551613
# MDST43_seed_compound_fMRI   20.200341
# MDST44_seed_compound_fMRI   14.468351
# memory_roi                        NaN

# %%
sort = True

#----------------------------------------------------------------User Input Above----------------------------------------------------------------
sheet_name = 'AD_Clinical_Scores'
alphab_cols = 'C, D, E, F, G, J, V'
clin_df = pd.read_excel(clin_path, sheet_name=sheet_name, usecols=alphab_cols, nrows=50)
print('Num NaNs: ', clin_df.isna().sum().sum())
# clin_df.tail(5)
if sort:
    clin_df.sort_values(by='Patient # CDR, ADAS', ascending=True, inplace=True)
    clin_df = clin_df.set_index('Patient # CDR, ADAS')

# clin_df = pd.read_csv(clin_path)
y_df = clin_df
display(y_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 6
#       4 sheet_name = 'AD_Clinical_Scores'
#       5 alphab_cols = 'C, D, E, F, G, J, V'
# ----> 6 clin_df = pd.read_excel(clin_path, sheet_name=sheet_name, usecols=alphab_cols, nrows=50)
#       7 print('Num NaNs: ', clin_df.isna().sum().sum())
#       8 # clin_df.tail(5)
#
# File /usr/local/Caskroom/mambaforge/base/envs/nimlab_py310/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File /usr/local/Caskroom/mambaforge/base/envs/nimlab_py310/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /usr/local/Caskroom/mambaforge/base/envs/nimlab_py310/lib/python3.10/site-packages/pandas/io/excel/_base.py:482, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     480 if not isinstance(io, ExcelFile):
#     481     should_close = True
# --> 482     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     483 elif engine and engine != io.engine:
#     484     raise ValueError(
#     485         "Engine should not be specified when passing "
#     486         "an ExcelFile - ExcelFile already has the engine set"
#     487     )
#
# File /usr/local/Caskroom/mambaforge/base/envs/nimlab_py310/lib/python3.10/site-packages/pandas/io/excel/_base.py:1656, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1652     ext = inspect_excel_format(
#    1653         content_or_path=path_or_buffer, storage_options=storage_options
#    1654     )
#    1655     if ext is None:
# -> 1656         raise ValueError(
#    1657             "Excel file format cannot be determined, you must specify "
#    1658             "an engine manually."
#    1659         )
#    1661 engine = config.get_option(f"io.excel.{ext}.reader", silent=True)
#    1662 if engine == "auto":
#
# ValueError: Excel file format cannot be determined, you must specify an engine manually.

# %%
corr_df
# Out:
#      spatial_correlation Patient # CDR, ADAS
# 116             0.033496                 116
# 139             0.113326                 139
# 147             0.101976                 147
# 135             0.114333                 135
# 101             0.006817                 101
# 150            -0.110989                 150
# 122            -0.031897                 122
# 146            -0.018234                 146
# 138             0.001325                 138
# 134            -0.057126                 134
# 123             0.047217                 123
# 149            -0.038707                 149
# 137             0.092675                 137
# 118             0.031447                 118
# 114            -0.116223                 114
# 145            -0.014180                 145
# 120             0.011392                 120
# 103            -0.050606                 103
# 119            -0.064067                 119
# 148             0.034700                 148
# 144             0.089580                 144
# 115            -0.040042                 115
# 121            -0.158866                 121
# 102            -0.093413                 102
# 105             0.003379                 105
# 109            -0.056924                 109
# 126             0.035126                 126
# 143            -0.070514                 143
# 131            -0.086798                 131
# 104            -0.041985                 104
# 127            -0.022103                 127
# 108            -0.068730                 108
# 113            -0.025566                 113
# 142            -0.001880                 142
# 130             0.008041                 130
# 124             0.010488                 124
# 128            -0.009918                 128
# 107            -0.017072                 107
# 133            -0.026520                 133
# 141            -0.047045                 141
# 110             0.001942                 110
# 125            -0.069902                 125
# 106            -0.020589                 106
# 129            -0.048916                 129
# 111            -0.000725                 111
# 140             0.039133                 140

# %%
#Merge and save
##--------------------------------OPTION A: Custom Merge
from calvin_utils.merge_dataframes import merge_dataframes
# data_df = merge_dataframes(y_df, corr_df)
# # data_df['Patient # CDR, ADAS'] = x_df.index.values.tolist()[0:-1]
# try:
#     data_df = data_df.drop(index=np.NaN)
# except:
#     print('No NaNs in index')
# display(data_df)
##--------------------------------OPTION B: Perform a Union on to Patient ID
# y_df['Patient # CDR, ADAS']=y_df['Patient # CDR, ADAS'].astype(int)
# corr_df.reset_index(inplace=True, drop=True)
corr_df['Patient # CDR, ADAS']=corr_df['Patient # CDR, ADAS'].astype(int)
data_df = y_df.merge(corr_df, on='Patient # CDR, ADAS', right_index=False)
try:
    data_df.pop('index')
except:
    print('nothing to pop')
try:
    data_df.pop('level_0')
except:
    print('nothing to pop')
display(data_df)
data_df.to_csv(out_dir + '_revised_with_clinical_data_dataframe.csv')
print('saved to:', out_dir)
# Out:
# nothing to pop
# nothing to pop
#     Patient # CDR, ADAS Randomization Arm  Age at DOS  Baseline ADAS-Cog11  \
# 0                   101         sham-stim          62                 28.0
# 1                   102         stim-sham          77                 22.0
# 2                   103         sham-stim          76                 19.0
# 3                   104         stim-sham          65                 17.0
# 4                   105               NaN          50                 19.0
# 5                   106         stim-sham          66                 13.0
# 6                   107               NaN          64                 13.0
# 7                   108               NaN          60                 24.0
# 8                   109         sham-stim          72                 23.0
# 9                   110         sham-stim          72                 13.0
# 10                  111               NaN          62                 12.0
# 11                  113         stim-sham          69                 15.0
# 12                  114         sham-stim          67                 31.0
# 13                  115               NaN          60                 29.0
# 14                  116         stim-sham          67                 19.0
# 15                  118         sham-stim          52                 32.0
# 16                  119         stim-sham          75                 16.0
# 17                  120               NaN          68                 18.0
# 18                  121         sham-stim          72                 23.0
# 19                  122         stim-sham          58                 15.0
# 20                  123         sham-stim          47                 22.0
# 21                  124         stim-sham          61                 16.0
# 22                  125         stim-sham          73                 16.0
# 23                  126         stim-sham          69                 21.0
# 24                  127         sham-stim          74                 17.0
# 25                  128         sham-stim          72                 24.0
# 26                  129         sham-stim          69                 28.0
# 27                  130         stim-sham          66                 14.0
# 28                  131         stim-sham          68                 20.0
# 29                  133         sham-stim          74                 16.0
# 30                  134         stim-sham          66                 17.0
# 31                  135         sham-stim          57                 35.0
# 32                  137         stim-sham          57                 22.0
# 33                  138         stim-sham          72                 21.0
# 34                  139         sham-stim          58                 17.0
# 35                  140         stim-sham          73                 22.0
# 36                  141         sham-stim          72                 19.0
# 37                  142         stim-sham          77                 18.0
# 38                  143         sham-stim          71                 16.0
# 39                  144         stim-sham          79                 13.0
# 40                  145         stim-sham          74                 18.0
# 41                  146         sham-stim          76                 11.0
# 42                  147         stim-sham          59                 21.0
# 43                  148         stim-sham          51                 13.0
# 44                  149         sham-stim          77                 10.0
# 45                  150         sham-stim          71                 22.0
#
#     Baseline CDR (sum of squares)  % Change from baseline (ADAS-Cog11)  \
# 0                             5.0                           -21.428571
# 1                             6.5                           -36.363636
# 2                             7.0                           -78.947368
# 3                             7.0                          -129.411765
# 4                             NaN                           -10.526316
# 5                             3.0                           -38.461538
# 6                             NaN                           -15.384615
# 7                             NaN                           -29.166667
# 8                             9.0                           -30.434783
# 9                             5.0                           -84.615385
# 10                            NaN                            41.666667
# 11                            5.5                           -60.000000
# 12                            7.0                           -16.129032
# 13                            NaN                           -48.275862
# 14                            4.0                           -36.842105
# 15                            6.0                            -3.125000
# 16                            5.0                           -81.250000
# 17                            NaN                           -27.777778
# 18                            5.5                            -4.347826
# 19                            5.0                          -140.000000
# 20                            5.0                            54.545455
# 21                            5.0                           -18.750000
# 22                            4.0                           -37.500000
# 23                            5.0                          -100.000000
# 24                            5.0                           -76.470588
# 25                            7.0                           -20.833333
# 26                            5.5                           -35.714286
# 27                            2.0                            -7.142857
# 28                            3.5                           -40.000000
# 29                            4.5                             6.250000
# 30                            3.5                            29.411765
# 31                            4.5                           -45.714286
# 32                            6.5                           -77.272727
# 33                            4.5                            -9.523810
# 34                            2.0                          -105.882353
# 35                            4.0                            18.181818
# 36                            9.0                             0.000000
# 37                            1.0                             5.555556
# 38                            3.0                             6.250000
# 39                            3.0                           -61.538462
# 40                            3.5                             5.555556
# 41                            4.0                           -54.545455
# 42                            3.0                            -4.761905
# 43                            3.5                          -207.692308
# 44                            5.0                           -90.000000
# 45                            4.5                            13.636364
#
#     % Change from baseline (CDR)  spatial_correlation
# 0                     -40.000000             0.006817
# 1                     -69.230769            -0.093413
# 2                     -42.857143            -0.050606
# 3                     -71.428571            -0.041985
# 4                            NaN             0.003379
# 5                     -50.000000            -0.020589
# 6                            NaN            -0.017072
# 7                            NaN            -0.068730
# 8                     -44.444444            -0.056924
# 9                     -80.000000             0.001942
# 10                           NaN            -0.000725
# 11                   -100.000000            -0.025566
# 12                      0.000000            -0.116223
# 13                           NaN            -0.040042
# 14                    -37.500000             0.033496
# 15                   -100.000000             0.031447
# 16                   -100.000000            -0.064067
# 17                           NaN             0.011392
# 18                   -118.181818            -0.158866
# 19                           NaN            -0.031897
# 20                     10.000000             0.047217
# 21                    -20.000000             0.010488
# 22                    -75.000000            -0.069902
# 23                   -240.000000             0.035126
# 24                    -80.000000            -0.022103
# 25                    -28.571429            -0.009918
# 26                   -100.000000            -0.048916
# 27                    -25.000000             0.008041
# 28                      0.000000            -0.086798
# 29                           NaN            -0.026520
# 30                      0.000000            -0.057126
# 31                   -211.111111             0.114333
# 32                    -38.461538             0.092675
# 33                    -77.777778             0.001325
# 34                   -100.000000             0.113326
# 35                      0.000000             0.039133
# 36                     11.111111            -0.047045
# 37                   -400.000000            -0.001880
# 38                    -16.666667            -0.070514
# 39                   -133.333333             0.089580
# 40                   -100.000000            -0.014180
# 41                    -50.000000            -0.018234
# 42                   -100.000000             0.101976
# 43                   -157.142857             0.034700
# 44                    -20.000000            -0.038707
# 45                      0.000000            -0.110989
# saved to: /Users/cu135/Dropbox (Partners HealthCare)/memory/functional_networks/spcorrel/ad_dbs_to_gm_z_scores_unthresholded/pearson_correlation_df

# %% [markdown]
# ## For TMS DATA

# %%
y_df = pd.read_csv(clin_path)
y_df
# Out:
#                ID  preOP  postOP  diff. Mattis  perc_change_mattis  \
# 0   01_MD_STN_WUE    141     133             8            5.673759
# 1   02_MD_STN_WUE    139     142            -3           -2.158273
# 2   03_MD_STN_WUE    144     142             2            1.388889
# 3   04_MD_STN_WUE    140     137             3            2.142857
# 4   06_MD_STN_WUE    142     141             1            0.704225
# 5   07_MD_STN_WUE    141     140             1            0.709220
# 6   09_MD_STN_WUE    140     137             3            2.142857
# 7   11_MD_STN_WUE    144     143             1            0.694444
# 8   12_MD_STN_WUE    136     136             0            0.000000
# 9   14_MD_STN_WUE    143     144            -1           -0.699301
# 10  15_MD_STN_WUE    144     133            11            7.638889
# 11  17_MD_STN_WUE    144     144             0            0.000000
# 12  18_MD_STN_WUE    139     140            -1           -0.719424
# 13  19_MD_STN_WUE    144     142             2            1.388889
# 14  21_MD_STN_WUE    142     128            14            9.859155
# 15  22_MD_STN_WUE    143     143             0            0.000000
# 16  23_MD_STN_WUE    141     139             2            1.418440
# 17  24_MD_STN_WUE    138     125            13            9.420290
# 18  26_MD_STN_WUE    140     140             0            0.000000
# 19  27_MD_STN_WUE    144     142             2            1.388889
# 20  28_MD_STN_WUE    138     141            -3           -2.173913
# 21  29_MD_STN_WUE    141     141             0            0.000000
# 22  30_MD_STN_WUE    144     142             2            1.388889
# 23  31_MD_STN_WUE    138     140            -2           -1.449275
# 24  33_MD_STN_WUE    143     141             2            1.398601
# 25  34_MD_STN_WUE    136     134             2            1.470588
# 26  36_MD_STN_WUE    143     139             4            2.797203
# 27  37_MD_STN_WUE    139     136             3            2.158273
# 28  38_MD_STN_WUE    144     143             1            0.694444
# 29  39_MD_STN_WUE    142     136             6            4.225352
# 30  43_MD_STN_WUE    141     137             4            2.836879
# 31  44_MD_STN_WUE    143     143             0            0.000000
#
#     perc_improvement  Age_at_implant  z_score_sbc_gm  z_score_sbc_csf
# 0          -5.673759            57.0        6.512501        -0.398597
# 1           2.158273            50.0        6.534732         1.800272
# 2          -1.388889            62.0        5.296124         0.482642
# 3          -2.142857            50.0        4.737163         0.244241
# 4          -0.704225            60.0        6.755988         0.428132
# 5          -0.709220            73.0        9.615373        -0.967502
# 6          -2.142857            64.0        2.727865         1.893940
# 7          -0.694444            62.0        9.690537         0.429385
# 8           0.000000            54.0        8.206324         1.024292
# 9           0.699301            49.0       11.117583        -0.563379
# 10         -7.638889            46.0        1.180134        -1.200578
# 11          0.000000            52.0        9.062763        -0.405489
# 12          0.719424            46.0        1.134612        -1.780761
# 13         -1.388889            64.0        9.697947        -0.594393
# 14         -9.859155            58.0        7.641011        -0.163329
# 15          0.000000            57.0        2.299116         2.618543
# 16         -1.418440            68.0        1.061566        -1.854694
# 17         -9.420290             NaN             NaN              NaN
# 18          0.000000            79.0        5.612657         1.041522
# 19         -1.388889            61.0        2.831611         1.913677
# 20          2.173913            56.0       11.802522        -1.652319
# 21          0.000000            47.0        4.515907        -0.320279
# 22         -1.388889            58.0        6.973009         2.352260
# 23          1.449275            64.0       -8.205764         5.376292
# 24         -1.398601            60.0        9.086053         0.302823
# 25         -1.470588             NaN             NaN              NaN
# 26         -2.797203            52.0        8.416993         1.409619
# 27         -2.158273            64.0        5.021937         2.678691
# 28         -0.694444             NaN             NaN              NaN
# 29         -4.225352             NaN             NaN              NaN
# 30         -2.836879             NaN             NaN              NaN
# 31          0.000000             NaN             NaN              NaN

# %%
subs_list = y_df['ID'].to_list()
subs_list_basename = [os.path.basename(sub).split('_')[0] for sub in subs_list]
y_df['sub'] = subs_list_basename
y_df
# Out:
#                ID  preOP  postOP  diff. Mattis  perc_change_mattis  \
# 0   01_MD_STN_WUE    141     133             8            5.673759
# 1   02_MD_STN_WUE    139     142            -3           -2.158273
# 2   03_MD_STN_WUE    144     142             2            1.388889
# 3   04_MD_STN_WUE    140     137             3            2.142857
# 4   06_MD_STN_WUE    142     141             1            0.704225
# 5   07_MD_STN_WUE    141     140             1            0.709220
# 6   09_MD_STN_WUE    140     137             3            2.142857
# 7   11_MD_STN_WUE    144     143             1            0.694444
# 8   12_MD_STN_WUE    136     136             0            0.000000
# 9   14_MD_STN_WUE    143     144            -1           -0.699301
# 10  15_MD_STN_WUE    144     133            11            7.638889
# 11  17_MD_STN_WUE    144     144             0            0.000000
# 12  18_MD_STN_WUE    139     140            -1           -0.719424
# 13  19_MD_STN_WUE    144     142             2            1.388889
# 14  21_MD_STN_WUE    142     128            14            9.859155
# 15  22_MD_STN_WUE    143     143             0            0.000000
# 16  23_MD_STN_WUE    141     139             2            1.418440
# 17  24_MD_STN_WUE    138     125            13            9.420290
# 18  26_MD_STN_WUE    140     140             0            0.000000
# 19  27_MD_STN_WUE    144     142             2            1.388889
# 20  28_MD_STN_WUE    138     141            -3           -2.173913
# 21  29_MD_STN_WUE    141     141             0            0.000000
# 22  30_MD_STN_WUE    144     142             2            1.388889
# 23  31_MD_STN_WUE    138     140            -2           -1.449275
# 24  33_MD_STN_WUE    143     141             2            1.398601
# 25  34_MD_STN_WUE    136     134             2            1.470588
# 26  36_MD_STN_WUE    143     139             4            2.797203
# 27  37_MD_STN_WUE    139     136             3            2.158273
# 28  38_MD_STN_WUE    144     143             1            0.694444
# 29  39_MD_STN_WUE    142     136             6            4.225352
# 30  43_MD_STN_WUE    141     137             4            2.836879
# 31  44_MD_STN_WUE    143     143             0            0.000000
#
#     perc_improvement  Age_at_implant  z_score_sbc_gm  z_score_sbc_csf sub
# 0          -5.673759            57.0        6.512501        -0.398597  01
# 1           2.158273            50.0        6.534732         1.800272  02
# 2          -1.388889            62.0        5.296124         0.482642  03
# 3          -2.142857            50.0        4.737163         0.244241  04
# 4          -0.704225            60.0        6.755988         0.428132  06
# 5          -0.709220            73.0        9.615373        -0.967502  07
# 6          -2.142857            64.0        2.727865         1.893940  09
# 7          -0.694444            62.0        9.690537         0.429385  11
# 8           0.000000            54.0        8.206324         1.024292  12
# 9           0.699301            49.0       11.117583        -0.563379  14
# 10         -7.638889            46.0        1.180134        -1.200578  15
# 11          0.000000            52.0        9.062763        -0.405489  17
# 12          0.719424            46.0        1.134612        -1.780761  18
# 13         -1.388889            64.0        9.697947        -0.594393  19
# 14         -9.859155            58.0        7.641011        -0.163329  21
# 15          0.000000            57.0        2.299116         2.618543  22
# 16         -1.418440            68.0        1.061566        -1.854694  23
# 17         -9.420290             NaN             NaN              NaN  24
# 18          0.000000            79.0        5.612657         1.041522  26
# 19         -1.388889            61.0        2.831611         1.913677  27
# 20          2.173913            56.0       11.802522        -1.652319  28
# 21          0.000000            47.0        4.515907        -0.320279  29
# 22         -1.388889            58.0        6.973009         2.352260  30
# 23          1.449275            64.0       -8.205764         5.376292  31
# 24         -1.398601            60.0        9.086053         0.302823  33
# 25         -1.470588             NaN             NaN              NaN  34
# 26         -2.797203            52.0        8.416993         1.409619  36
# 27         -2.158273            64.0        5.021937         2.678691  37
# 28         -0.694444             NaN             NaN              NaN  38
# 29         -4.225352             NaN             NaN              NaN  39
# 30         -2.836879             NaN             NaN              NaN  43
# 31          0.000000             NaN             NaN              NaN  44

# %%
corr_df
# Out:
#                            memory_roi
# Patient # CDR, ADAS
# MDST01_seed_compound_fMRI   30.376565
# MDST02_seed_compound_fMRI   16.295870
# MDST04_seed_compound_fMRI   21.207602
# MDST03_seed_compound_fMRI   30.900051
# MDST06_seed_compound_fMRI   23.577739
# MDST07_seed_compound_fMRI   36.657479
# MDST09_seed_compound_fMRI   19.955774
# MDST11_seed_compound_fMRI   15.156220
# MDST12_seed_compound_fMRI   28.328345
# MDST14_seed_compound_fMRI   19.619016
# MDST15_seed_compound_fMRI   39.316089
# MDST17_seed_compound_fMRI   30.014730
# MDST19_seed_compound_fMRI   23.128431
# MDST18_seed_compound_fMRI   15.781874
# MDST21_seed_compound_fMRI   26.016428
# MDST22_seed_compound_fMRI   19.953155
# MDST23_seed_compound_fMRI   15.519790
# MDST24_seed_compound_fMRI   24.237392
# MDST26_seed_compound_fMRI   24.468157
# MDST27_seed_compound_fMRI   18.800226
# MDST28_seed_compound_fMRI   32.297293
# MDST29_seed_compound_fMRI   29.015201
# MDST30_seed_compound_fMRI   18.674670
# MDST31_seed_compound_fMRI   15.353030
# MDST33_seed_compound_fMRI   15.050219
# MDST34_seed_compound_fMRI   34.047011
# MDST36_seed_compound_fMRI   17.382020
# MDST37_seed_compound_fMRI   17.978233
# MDST38_seed_compound_fMRI   14.611144
# MDST39_seed_compound_fMRI   21.551613
# MDST43_seed_compound_fMRI   20.200341
# MDST44_seed_compound_fMRI   14.468351
# memory_roi                        NaN

# %%
# x_df.drop(index=0, inplace=True)
corr_df = corr_df.iloc[0:-1, :]
subs_list = corr_df.index.to_list()
print(subs_list)
subs_list_basename = [os.path.basename(sub).split('MDST')[1].split('_')[0] for sub in subs_list]
corr_df['sub'] = subs_list_basename
# Out:
# ['MDST01_seed_compound_fMRI', 'MDST02_seed_compound_fMRI', 'MDST04_seed_compound_fMRI', 'MDST03_seed_compound_fMRI', 'MDST06_seed_compound_fMRI', 'MDST07_seed_compound_fMRI', 'MDST09_seed_compound_fMRI', 'MDST11_seed_compound_fMRI', 'MDST12_seed_compound_fMRI', 'MDST14_seed_compound_fMRI', 'MDST15_seed_compound_fMRI', 'MDST17_seed_compound_fMRI', 'MDST19_seed_compound_fMRI', 'MDST18_seed_compound_fMRI', 'MDST21_seed_compound_fMRI', 'MDST22_seed_compound_fMRI', 'MDST23_seed_compound_fMRI', 'MDST24_seed_compound_fMRI', 'MDST26_seed_compound_fMRI', 'MDST27_seed_compound_fMRI', 'MDST28_seed_compound_fMRI', 'MDST29_seed_compound_fMRI', 'MDST30_seed_compound_fMRI', 'MDST31_seed_compound_fMRI', 'MDST33_seed_compound_fMRI', 'MDST34_seed_compound_fMRI', 'MDST36_seed_compound_fMRI', 'MDST37_seed_compound_fMRI', 'MDST38_seed_compound_fMRI', 'MDST39_seed_compound_fMRI', 'MDST43_seed_compound_fMRI', 'MDST44_seed_compound_fMRI']
# /var/folders/82/946tskyj68b6htgvndtppmz80000gp/T/ipykernel_89348/2017463803.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   corr_df['sub'] = subs_list_basename

# %%
data_df = y_df.merge(corr_df, on='sub', right_index=False)
data_df
# Out:
#                ID  preOP  postOP  diff. Mattis  perc_change_mattis  \
# 0   01_MD_STN_WUE    141     133             8            5.673759
# 1   02_MD_STN_WUE    139     142            -3           -2.158273
# 2   03_MD_STN_WUE    144     142             2            1.388889
# 3   04_MD_STN_WUE    140     137             3            2.142857
# 4   06_MD_STN_WUE    142     141             1            0.704225
# 5   07_MD_STN_WUE    141     140             1            0.709220
# 6   09_MD_STN_WUE    140     137             3            2.142857
# 7   11_MD_STN_WUE    144     143             1            0.694444
# 8   12_MD_STN_WUE    136     136             0            0.000000
# 9   14_MD_STN_WUE    143     144            -1           -0.699301
# 10  15_MD_STN_WUE    144     133            11            7.638889
# 11  17_MD_STN_WUE    144     144             0            0.000000
# 12  18_MD_STN_WUE    139     140            -1           -0.719424
# 13  19_MD_STN_WUE    144     142             2            1.388889
# 14  21_MD_STN_WUE    142     128            14            9.859155
# 15  22_MD_STN_WUE    143     143             0            0.000000
# 16  23_MD_STN_WUE    141     139             2            1.418440
# 17  24_MD_STN_WUE    138     125            13            9.420290
# 18  26_MD_STN_WUE    140     140             0            0.000000
# 19  27_MD_STN_WUE    144     142             2            1.388889
# 20  28_MD_STN_WUE    138     141            -3           -2.173913
# 21  29_MD_STN_WUE    141     141             0            0.000000
# 22  30_MD_STN_WUE    144     142             2            1.388889
# 23  31_MD_STN_WUE    138     140            -2           -1.449275
# 24  33_MD_STN_WUE    143     141             2            1.398601
# 25  34_MD_STN_WUE    136     134             2            1.470588
# 26  36_MD_STN_WUE    143     139             4            2.797203
# 27  37_MD_STN_WUE    139     136             3            2.158273
# 28  38_MD_STN_WUE    144     143             1            0.694444
# 29  39_MD_STN_WUE    142     136             6            4.225352
# 30  43_MD_STN_WUE    141     137             4            2.836879
# 31  44_MD_STN_WUE    143     143             0            0.000000
#
#     perc_improvement  Age_at_implant  z_score_sbc_gm  z_score_sbc_csf sub  \
# 0          -5.673759            57.0        6.512501        -0.398597  01
# 1           2.158273            50.0        6.534732         1.800272  02
# 2          -1.388889            62.0        5.296124         0.482642  03
# 3          -2.142857            50.0        4.737163         0.244241  04
# 4          -0.704225            60.0        6.755988         0.428132  06
# 5          -0.709220            73.0        9.615373        -0.967502  07
# 6          -2.142857            64.0        2.727865         1.893940  09
# 7          -0.694444            62.0        9.690537         0.429385  11
# 8           0.000000            54.0        8.206324         1.024292  12
# 9           0.699301            49.0       11.117583        -0.563379  14
# 10         -7.638889            46.0        1.180134        -1.200578  15
# 11          0.000000            52.0        9.062763        -0.405489  17
# 12          0.719424            46.0        1.134612        -1.780761  18
# 13         -1.388889            64.0        9.697947        -0.594393  19
# 14         -9.859155            58.0        7.641011        -0.163329  21
# 15          0.000000            57.0        2.299116         2.618543  22
# 16         -1.418440            68.0        1.061566        -1.854694  23
# 17         -9.420290             NaN             NaN              NaN  24
# 18          0.000000            79.0        5.612657         1.041522  26
# 19         -1.388889            61.0        2.831611         1.913677  27
# 20          2.173913            56.0       11.802522        -1.652319  28
# 21          0.000000            47.0        4.515907        -0.320279  29
# 22         -1.388889            58.0        6.973009         2.352260  30
# 23          1.449275            64.0       -8.205764         5.376292  31
# 24         -1.398601            60.0        9.086053         0.302823  33
# 25         -1.470588             NaN             NaN              NaN  34
# 26         -2.797203            52.0        8.416993         1.409619  36
# 27         -2.158273            64.0        5.021937         2.678691  37
# 28         -0.694444             NaN             NaN              NaN  38
# 29         -4.225352             NaN             NaN              NaN  39
# 30         -2.836879             NaN             NaN              NaN  43
# 31          0.000000             NaN             NaN              NaN  44
#
#     memory_roi
# 0    30.376565
# 1    16.295870
# 2    30.900051
# 3    21.207602
# 4    23.577739
# 5    36.657479
# 6    19.955774
# 7    15.156220
# 8    28.328345
# 9    19.619016
# 10   39.316089
# 11   30.014730
# 12   15.781874
# 13   23.128431
# 14   26.016428
# 15   19.953155
# 16   15.519790
# 17   24.237392
# 18   24.468157
# 19   18.800226
# 20   32.297293
# 21   29.015201
# 22   18.674670
# 23   15.353030
# 24   15.050219
# 25   34.047011
# 26   17.382020
# 27   17.978233
# 28   14.611144
# 29   21.551613
# 30   20.200341
# 31   14.468351

# %%
data_df.to_csv(out_dir+'_all_info_with_clinical_data.csv')
